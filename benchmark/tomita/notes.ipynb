# %% [markdown]
# В main.py код для связи Томиты и Питона. Чтобы воспроизвести эксперимент, нужно скачать бинарник Томиты с https://tech.yandex.ru/tomita/ и положить его в папку tomita.

# %%
# %run -n main.py

# %% [markdown]
# # Сравнение скорости Наташи и Томиты при извлечении имён

# %% [markdown]
# Попробуем сравнить производительность Наташи и Томиты на задаче извлечения имён. Грамматики для Томиты для работы с именами лежат в tomita/algfio. Они повторяют пример https://github.com/yandex/tomita-parser/tree/master/examples/algfio из репозитория Томиты. Наташа использует стандартный NamesExtractor. Будем делать замеры на двух датасетах: отзывы о воспистателях детских садов и тексты новостей c lenta.ru.
#
# Томита извлекает имена в ~30 раз быстрее, чем Наташа. Если запускать Наташу под Pypy, разрыв сокращается: Томита в ~6 раз быстрее.
#
# <table>
#     <th>
#         <td></td>
#         <td>Наташа, текстов в секунду</td>
#         <td>Томита</td>
#         <td>Наташа под Pypy</td>
#         <td>Томита / Наташа</td>
#         <td>Томита / Наташа под Pypy</td>
#     </th>
#     <tr>
#         <td>Отзывы<td>
#         <td>7.4 </td>
#         <td>212.8</td>
#         <td>31.2</td>
#         <td>28.5</td>
#         <td>6.8</td>
#     <tr>
#     <tr>
#         <td>Новости<td>
#         <td>4.6</td>
#         <td>137</td>
#         <td>23.3</td>
#         <td>29.8</td>
#         <td>5.9</td>
#     <tr>
# </table>
#
# На текстах с отзывами у обоих решений очень хорошее качество — точность ~95%. В новостях чаще встречаются иностранные имена, Наташа с ними работает плохо, качество получается ~75%. Визуально Томита справляется лучше, точная оценка не делалась.
#
# С задачей извлечения имён Томита справляется лучше и по производительности и по качеству разметки.

# %% [markdown]
# # Отзывы

# %%
reviews = list(load_lines(REVIEWS))

# %% [markdown]
# Производительность Наташи 7.4 текстов в секунду (1000 текстов за 135 секунд)

# %%
# %%time
extractor = NamesExtractor()
records1 = [extractor(_) for _ in reviews]
# Out:
# CPU times: user 2min 12s, sys: 1.84 s, total: 2min 13s
# Wall time: 2min 15s

# %% [markdown]
# Производительность Томиты 212.8 текстов в секунду (10 000 текстов за 47 секунд)

# %%
# %%time
records2 = list(run_algfio_tomita(reviews * 10))
# Out:
# CPU times: user 2.65 s, sys: 2.08 s, total: 4.73 s
# Wall time: 47.1 s

# %% [markdown]
# Попробуем ещё запустить Наташу под Pypy.
#
# ```bash
# time pypy pypy.py reviews.txt
# # 26,90s user 1,17s system 87% cpu 31,991 total
# ```
#
# Получается 31.2 текста в секунду

# %% [markdown]
# Убедимся, что оба решения извлекают что-то разумное. В каждой паре первой идёт разметка Наташи, второй — Томиты. Видно, что в большинстве случаев ответы совпадают. Бывает ошибки и с той и с другой стороны.
#
# Ошибки Томиты:
# - Не проверяется согласование частей имени: Светлана Николаевне, Светлане Юрьевне Федоровне
# - Слова, которые не являются именами: "... с весенним праздником 8 МАРТА", "... проявили ЛЮБОВЬ". "Марта" и "любовь" здесь не имена. В "... группы Колокольчики Галине Ивановне" "Колокольчики" не фамилия.
#
# Ошибки Наташи:
# - Не ловит сложные фамилии: "Мацаль Елене", "Лагуненок Валентине", "Войтик Марине", "А. Дистервег"
# - Не очень сложные фамилии тоже иногда не ловит: "Прусаковой Татьяны Николаевны", "Цаплина Елена", "Евгений Филькин"

# %%
# %run -n main.py
records = list(zip(reviews, records1, records2))
random_seed(41)
for text, matches1_, matches2_ in sample(records, 10):
    spans1 = sorted(_.span for _ in matches1_)
    spans2 = sorted(_.span for _ in matches2_)
    if spans1 != spans2:
        show_markup(text, spans1)
        print('-------------')
        show_markup(text, spans2)
        print('=============')
# Out:
# <style>
#
# .markup {
#     white-space: pre-wrap;
# }
#
# .markup > mark {
#     line-height: 1;
#     display: inline-block;
#     border-radius: 0.25em;
#     border: 1px solid #fdf07c;
#     background: #ffffc2;
# }
#
# .markup > mark > .index {
#     font-size: 0.7em;
#     vertical-align: top;
#     margin-left: 0.1em;
# }
#     </style><div class="markup tex2jax_ignore">Присоединяюсь ко всем поздравлениям и положительным отзывам. Спасибо огромное коллективу нашего садика! У меня двое детей ходят в этот садик, в самую младшую группу <mark>Алиса Павлова<span class="index">0</span></mark> и в старшую группу <mark>Макар Павлов<span class="index">1</span></mark>. Про работу наших воспитателей младшей группы лучше не скажешь, чем мой ребенок <mark>Алиса<span class="index">2</span></mark>, которая уже в субботу утром говорит, что хочет в садик и когда мы туда пойдем. Спасибо вам <mark>Ольга Викторовна<span class="index">3</span></mark>, <mark>Татьяна Рафаиловна<span class="index">4</span></mark> и <mark>Зоя Павловна<span class="index">5</span></mark>! Спасибо воспитателям старшей группы <mark>Марие Сергеевне<span class="index">6</span></mark> и <mark>Екатерине Николаевне<span class="index">7</span></mark>, <mark>Макар<span class="index">8</span></mark> с удовольствием занимается, рассказывает как ему нравятся уроки, он спокоен и доволен. Большое спасибо <mark>Татьяне Федоровне<span class="index">9</span></mark> и <mark>Веронике Николаевне<span class="index">10</span></mark> за то, что вы организовываете такие чудесные выступления, за то, что прививаете патриотизм и любовь к русской культуре. Очень понравился танец шофера и танец с красной звездой, очень трогательно и оригинально, а так же спасибо за интересные костюмы и яркие оригинальные украшения для танцев.</div>
# -------------
# <style>
#
# .markup {
#     white-space: pre-wrap;
# }
#
# .markup > mark {
#     line-height: 1;
#     display: inline-block;
#     border-radius: 0.25em;
#     border: 1px solid #fdf07c;
#     background: #ffffc2;
# }
#
# .markup > mark > .index {
#     font-size: 0.7em;
#     vertical-align: top;
#     margin-left: 0.1em;
# }
#     </style><div class="markup tex2jax_ignore">Присоединяюсь ко всем поздравлениям и положительным отзывам. Спасибо огромное коллективу нашего садика! У меня двое детей ходят в этот садик, в самую младшую группу <mark>Алиса Павлова<span class="index">0</span></mark> и в старшую группу <mark>Макар Павлов<span class="index">1</span></mark>. Про работу наших воспитателей младшей группы лучше не скажешь, чем мой ребенок <mark>Алиса<span class="index">2</span></mark>, которая уже в субботу утром говорит, что хочет в садик и когда мы туда пойдем. Спасибо вам <mark>Ольга Викторовна<span class="index">3</span></mark>, <mark>Татьяна Рафаиловна<span class="index">4</span></mark> и <mark>Зоя Павловна<span class="index">5</span></mark>! Спасибо воспитателям старшей группы Марие Сергеевне и <mark>Екатерине Николаевне<span class="index">6</span></mark>, <mark>Макар<span class="index">7</span></mark> с удовольствием занимается, рассказывает как ему нравятся уроки, он спокоен и доволен. Большое спасибо <mark>Татьяне Федоровне<span class="index">8</span></mark> и <mark>Веронике Николаевне<span class="index">9</span></mark> за то, что вы организовываете такие чудесные выступления, за то, что прививаете патриотизм и любовь к русской культуре. Очень понравился танец шофера и танец с красной звездой, очень трогательно и оригинально, а так же спасибо за интересные костюмы и яркие оригинальные украшения для танцев.</div>
# =============
# <style>
#
# .markup {
#     white-space: pre-wrap;
# }
#
# .markup > mark {
#     line-height: 1;
#     display: inline-block;
#     border-radius: 0.25em;
#     border: 1px solid #fdf07c;
#     background: #ffffc2;
# }
#
# .markup > mark > .index {
#     font-size: 0.7em;
#     vertical-align: top;
#     margin-left: 0.1em;
# }
#     </style><div class="markup tex2jax_ignore">Мне хотелось бы выразить благодарность и признательность воспитателям детского сада 1691, особо отметить работу педагогов группы 5 "<mark>Буратино<span class="index">0</span></mark>" <mark>Завьяловой О.Н.<span class="index">1</span></mark>и <mark>Ефремовой В.Н.<span class="index">2</span></mark>! Это высоко-квалифицированные педагоги, заботливые и любящие наших детей! Спасибо Вам за труд!</div>
# -------------
# <style>
#
# .markup {
#     white-space: pre-wrap;
# }
#
# .markup > mark {
#     line-height: 1;
#     display: inline-block;
#     border-radius: 0.25em;
#     border: 1px solid #fdf07c;
#     background: #ffffc2;
# }
#
# .markup > mark > .index {
#     font-size: 0.7em;
#     vertical-align: top;
#     margin-left: 0.1em;
# }
#     </style><div class="markup tex2jax_ignore">Мне хотелось бы выразить благодарность и признательность воспитателям детского сада 1691, особо отметить работу педагогов группы 5 "Буратино" <mark>Завьяловой О.Н.<span class="index">0</span></mark>и <mark>Ефремовой В.Н.<span class="index">1</span></mark>! Это высоко-квалифицированные педагоги, заботливые и любящие наших детей! Спасибо Вам за труд!</div>
# =============
# <style>
#
# .markup {
#     white-space: pre-wrap;
# }
#
# .markup > mark {
#     line-height: 1;
#     display: inline-block;
#     border-radius: 0.25em;
#     border: 1px solid #fdf07c;
#     background: #ffffc2;
# }
#
# .markup > mark > .index {
#     font-size: 0.7em;
#     vertical-align: top;
#     margin-left: 0.1em;
# }
#     </style><div class="markup tex2jax_ignore">Давно я сам ходил в детский сад №893, а теперь и мой сын ходит в 3ю группу подготовишек ))  Ходим последний год, а потом в школу.  Ну что Вам сказать, этот садик можно назвать домашним.  Очень чистая и ухоженная зеленая территория которую всегда поддерживают в великолепном состоянии.  Здание садика старой постройки, прошу заметить именно старой постройки а не старое, что придает дополнительный уют.  С наружи небольшое здание а внутри уютная обстановка и атмосфера, все очень чисто и аккуратно.  Все это реально создает какую то домашнюю обстановку, ощущение что приводишь ребенка не просто в сад, а в место где всё свое родное.   Образовательный процесс увлекательный и оптимально сбалансирован.  По мимо каждодневных развивающих заданий и упражнений (пол квартиры уже в поделках и листах с задачами ) постоянно проводятся конкурсы и соревнования.  Что является дополнительной мотивирующей базой для ребёнка.  Мы и сами участвовали в веселых стартах )))  Великолепно организованные праздники и сценки которые постоянно проходят в актовом зале.  ВСЕ НА ВЫСШЕМ УРОВНЕ.   Что касается персонала садика.  ОБСОЛЮТНО ВСЕ кто работают с этом саду задействованы в образовательном процессе.   <mark>Филаткина Ирина Алексеевна<span class="index">0</span></mark> – Это отдельный разговор, с самой первой минуты общения этот человек поражает сочетанием качеств.  Все предельно четко, все на своих местах, полная организация учебного процесса.  При любом обращение вы получаете четкий и грамотный ответ.  <mark>Ирина Алексеевна<span class="index">1</span></mark> всегда, находит выход из любой сложившейся ситуации.  Если вы не жуткий нарушитель внутренних распорядков и правил которые должны всегда соблюдаться в таких заведениях поскольку весь работающий персонал напрямую отвечает за детей.  То любая проблема будет решена.   <mark>Иванова Наталья Сергеевна<span class="index">2</span></mark>, <mark>Базылева Ирина Викторовна<span class="index">3</span></mark> и нянечка <mark>Стряпушкина Ольга Петровна<span class="index">4</span></mark> – наши ГУРУ, мастера древних искусств, наставники и покровители.  Квинтэссенция доброты, нежности и строгости.  Строгости в том смысле, что дети по мимо доброты ласки и образования не предоставлены сами себе, а под строгим наблюдением и контролем.  Я строго за воспитание “У МЕНЯ НЕ ЗАБАЛУЕШЬ”  Все воспитатели которые вели нашего ребенка с первого дня достойны высочайшей похвалы.   Сотрудники охраны меня поражают все то время сколько мой сын ходит в Сад.  Они не просто сухо ответят тебе на вопрос но и пообщаются нормально с ребёнком, если надо сделают уместное замечание, пошутят.  Всем бы садикам таких сотрудников охраны.   Кухня – о этот запах когда входишь в садик во время приготовления пищи.  Не знаю как у кого, а у меня сразу выделяется слюна.  Меню которое каждый день вывешивается при входе в садик очень разнообразно.  Подумываю над тем, что бы давать сыну контейнеры в садик чтоб он мне приносил эту вкуснятину.   Ставлю твердую 5+ садику, <mark>Евгений<span class="index">5</span></mark> Филькин рекомендует садик №893.</div>
# -------------
# <style>
#
# .markup {
#     white-space: pre-wrap;
# }
#
# .markup > mark {
#     line-height: 1;
#     display: inline-block;
#     border-radius: 0.25em;
#     border: 1px solid #fdf07c;
#     background: #ffffc2;
# }
#
# .markup > mark > .index {
#     font-size: 0.7em;
#     vertical-align: top;
#     margin-left: 0.1em;
# }
#     </style><div class="markup tex2jax_ignore">Давно я сам ходил в детский сад №893, а теперь и мой сын ходит в 3ю группу подготовишек ))  Ходим последний год, а потом в школу.  Ну что Вам сказать, этот садик можно назвать домашним.  Очень чистая и ухоженная зеленая территория которую всегда поддерживают в великолепном состоянии.  Здание садика старой постройки, прошу заметить именно старой постройки а не старое, что придает дополнительный уют.  С наружи небольшое здание а внутри уютная обстановка и атмосфера, все очень чисто и аккуратно.  Все это реально создает какую то домашнюю обстановку, ощущение что приводишь ребенка не просто в сад, а в место где всё свое родное.   Образовательный процесс увлекательный и оптимально сбалансирован.  По мимо каждодневных развивающих заданий и упражнений (пол квартиры уже в поделках и листах с задачами ) постоянно проводятся конкурсы и соревнования.  Что является дополнительной мотивирующей базой для ребёнка.  Мы и сами участвовали в веселых стартах )))  Великолепно организованные праздники и сценки которые постоянно проходят в актовом зале.  ВСЕ НА ВЫСШЕМ УРОВНЕ.   Что касается персонала садика.  ОБСОЛЮТНО ВСЕ кто работают с этом саду задействованы в образовательном процессе.   <mark>Филаткина Ирина Алексеевна<span class="index">0</span></mark> – Это отдельный разговор, с самой первой минуты общения этот человек поражает сочетанием качеств.  Все предельно четко, все на своих местах, полная организация учебного процесса.  При любом обращение вы получаете четкий и грамотный ответ.  <mark>Ирина Алексеевна<span class="index">1</span></mark> всегда, находит выход из любой сложившейся ситуации.  Если вы не жуткий нарушитель внутренних распорядков и правил которые должны всегда соблюдаться в таких заведениях поскольку весь работающий персонал напрямую отвечает за детей.  То любая проблема будет решена.   <mark>Иванова Наталья Сергеевна<span class="index">2</span></mark>, <mark>Базылева Ирина Викторовна<span class="index">3</span></mark> и нянечка <mark>Стряпушкина Ольга Петровна<span class="index">4</span></mark> – наши <mark>ГУРУ<span class="index">5</span></mark>, мастера древних искусств, наставники и покровители.  Квинтэссенция доброты, нежности и строгости.  Строгости в том смысле, что дети по мимо доброты ласки и образования не предоставлены сами себе, а под строгим наблюдением и контролем.  Я строго за воспитание “У МЕНЯ НЕ ЗАБАЛУЕШЬ”  Все воспитатели которые вели нашего ребенка с первого дня достойны высочайшей похвалы.   Сотрудники охраны меня поражают все то время сколько мой сын ходит в Сад.  Они не просто сухо ответят тебе на вопрос но и пообщаются нормально с ребёнком, если надо сделают уместное замечание, пошутят.  Всем бы садикам таких сотрудников охраны.   Кухня – о этот запах когда входишь в садик во время приготовления пищи.  Не знаю как у кого, а у меня сразу выделяется слюна.  Меню которое каждый день вывешивается при входе в садик очень разнообразно.  Подумываю над тем, что бы давать сыну контейнеры в садик чтоб он мне приносил эту вкуснятину.   Ставлю твердую 5+ садику, <mark>Евгений Филькин<span class="index">6</span></mark> рекомендует садик №893.</div>
# =============
# <style>
#
# .markup {
#     white-space: pre-wrap;
# }
#
# .markup > mark {
#     line-height: 1;
#     display: inline-block;
#     border-radius: 0.25em;
#     border: 1px solid #fdf07c;
#     background: #ffffc2;
# }
#
# .markup > mark > .index {
#     font-size: 0.7em;
#     vertical-align: top;
#     margin-left: 0.1em;
# }
#     </style><div class="markup tex2jax_ignore">Хочется сказать ОГРОМНОЕ СПАСИБО воспитателю группы 7 "Бельчата" д/с 1803 <mark>Раиле<span class="index">0</span></mark> Абдуллаевне, за чуткое отношение к деткам. Благодаря ее любви к детям и своему делу, профессиональному подходу к вопросам воспитания, мы знаем что наши дети в надежных и любящих руках. <mark>Раиле<span class="index">1</span></mark> Абдуллаевна стала деткам второй мамой к которой они бегут на встречу с огромной радостью. ОГРОМНОЕ СПАСИБО помощнику воспитателя <mark>Татьяне Николаевне<span class="index">2</span></mark> без ее заботы наши " бельчата" не были бы такими ухоженными и довольными жизнью. Спасибо Вам большое, что Вы у нас есть.</div>
# -------------
# <style>
#
# .markup {
#     white-space: pre-wrap;
# }
#
# .markup > mark {
#     line-height: 1;
#     display: inline-block;
#     border-radius: 0.25em;
#     border: 1px solid #fdf07c;
#     background: #ffffc2;
# }
#
# .markup > mark > .index {
#     font-size: 0.7em;
#     vertical-align: top;
#     margin-left: 0.1em;
# }
#     </style><div class="markup tex2jax_ignore">Хочется сказать ОГРОМНОЕ СПАСИБО воспитателю группы 7 "Бельчата" д/с 1803 <mark>Раиле Абдуллаевне<span class="index">0</span></mark>, за чуткое отношение к деткам. Благодаря ее любви к детям и своему делу, профессиональному подходу к вопросам воспитания, мы знаем что наши дети в надежных и любящих руках. <mark>Раиле Абдуллаевна<span class="index">1</span></mark> стала деткам второй мамой к которой они бегут на встречу с огромной радостью. ОГРОМНОЕ СПАСИБО помощнику воспитателя <mark>Татьяне Николаевне<span class="index">2</span></mark> без ее заботы наши " бельчата" не были бы такими ухоженными и довольными жизнью. Спасибо Вам большое, что Вы у нас есть.</div>
# =============
# <style>
#
# .markup {
#     white-space: pre-wrap;
# }
#
# .markup > mark {
#     line-height: 1;
#     display: inline-block;
#     border-radius: 0.25em;
#     border: 1px solid #fdf07c;
#     background: #ffffc2;
# }
#
# .markup > mark > .index {
#     font-size: 0.7em;
#     vertical-align: top;
#     margin-left: 0.1em;
# }
#     </style><div class="markup tex2jax_ignore">Здраствуйте Уважаемый <mark>Константин Владимирович<span class="index">0</span></mark>!  Мои дети посещают садик (1отд). Дочка в 6-ой группе, сын в 5-ой.  Я бы хотела обратить ваше внимание на педагогов этих групп!  6-ая Группа. Дочка у этих воспитателей первый год, и каково мое удивление что она каждый вечер засыпает и ждет когда снова пойдет к любимым воспитателям! Это потрясающие воспитатели, которые заинтересованы в успехах детей,которые всей душой отдаются работе. Результат мы,как родители, видим дома счастливых детей, а так же воспитатели постоянно делают видео,фото и выкладывают все в Эл. Почту группы, тем самым "открыв нам двери" в период нахождения деток в саду.  Воспитатели ежедневно занимаются,заинтересовывают,играют с детьми.  <mark>Молодцова Марина Анатольевна<span class="index">1</span></mark>, <mark>Козлова Светлана Валерьевна<span class="index">2</span></mark> и <mark>Юлия Викторовна<span class="index">3</span></mark> (помощн.воспит)- это те люди которые достойно и с совестью работают в своей профессии!!  <mark>Светлана Валерьевна<span class="index">4</span></mark>- это их "вечный двигатель" она всегда что-то придумывает; снимает,монтирует видео; играет с детьми!  <mark>Марина Анатольевна<span class="index">5</span></mark>- это воспитатель,который учит наших деток доброте, хорошим поступкам; читает книги, рассказывает разные интересные рассказы (даже на прогулках она заинтересовывают деток:)  <mark>Юлия Викторовна<span class="index">6</span></mark> - добрая, отзывчивая воспитатель! Имея опыт общения с детьми девочкам с ней особо интересно наряжаться, играть в девчачьи игры, ну и конечно дети любят помогать ей дежурить.  Восхищаюсь тем,сколько они все вместе занимаются рисованием,лепкой, аппликациями с детьми. Это каждый вечер я слышу "мам пойдем покажу что мы делали сегодня" и я Вам не могу передать то чувство счастья и спокойствия за своего ребенка, отдавая его в сад.   5-ая Группа. Малыши. Да,там маленькие детки 3-4года. Но и у них воспитатели самой высшей категории!! Это идеальное подходящие два воспитателя. <mark>Ронжина Ольга Николаевна<span class="index">7</span></mark> - это воспитатель- учитель,она вторая "мама" нашим детям. Занимается развитием речи,математикой,лепкой и многим другим, и конечно же ставит сценки с нашими малышами, помогает детям "адаптироваться" к сцене. Имеет к каждому ребенку особый подход!  <mark>Коновалов<span class="index">8</span></mark> <mark>Елена Ивановна<span class="index">9</span></mark> (Еленовна Ивановна,как говорит сын:)- это творческий воспитатель, с ней детки с удовольствием занимаются рисованием,лепкой, играют в подвижные игры и считают её своим другом!  <mark>Светлана Викторовна<span class="index">10</span></mark>(помощн.воспит.)- "палочка выручалочка" в нашей группе. Всегда следит чтобы все были сыты, чистые, и смотрит за всеми детками, помогает и так же участвует в играх,выступлениях,зарядке- в общем незаменимый человек.  В группе всегда веселая,добрая атмосфера. Ежедневно они что то творят с воспитателями, рисуют,раскрашивать,лепят,танцуют...   Подводя итог,хочу сказать что КАЖДЫЙ из воспитателей 5 и 6 группы с уважением,вниманием относятся к родителям своих воспитанников. Всегда ответят на все вопросы,касающиеся своего ребенка,отвечают искренне и подробно! Я безумно рада,что мои дети в надежных руках. Я доверяю своих детей этим людям и знаю, что все они сделают максимум,чтобы не толькр обеспечить безопасный присмотр,они ещё и разнообразят веселый досуг малышам.  Прошу Вас отметить каждого педагога благодарностью от лица родителей.  Спасибо им за то,что родители,находясь на работе спокойны за своих чад.  Желаю вашей (нашей будущей) школе процветания и хороших результатов. И всем знакомым однозначно скажу,что наш сад и будущая школа лучшие в нашем районе!!   С уважением, <mark>Анна<span class="index">11</span></mark></div>
# -------------
# <style>
#
# .markup {
#     white-space: pre-wrap;
# }
#
# .markup > mark {
#     line-height: 1;
#     display: inline-block;
#     border-radius: 0.25em;
#     border: 1px solid #fdf07c;
#     background: #ffffc2;
# }
#
# .markup > mark > .index {
#     font-size: 0.7em;
#     vertical-align: top;
#     margin-left: 0.1em;
# }
#     </style><div class="markup tex2jax_ignore">Здраствуйте Уважаемый <mark>Константин Владимирович<span class="index">0</span></mark>!  Мои дети посещают садик (1отд). Дочка в 6-ой группе, сын в 5-ой.  Я бы хотела обратить ваше внимание на педагогов этих групп!  6-ая Группа. Дочка у этих воспитателей первый год, и каково мое удивление что она каждый вечер засыпает и ждет когда снова пойдет к любимым воспитателям! Это потрясающие воспитатели, которые заинтересованы в успехах детей,которые всей душой отдаются работе. Результат мы,как родители, видим дома счастливых детей, а так же воспитатели постоянно делают видео,фото и выкладывают все в <mark>Эл<span class="index">1</span></mark>. Почту группы, тем самым "открыв нам двери" в период нахождения деток в саду.  Воспитатели ежедневно занимаются,заинтересовывают,играют с детьми.  <mark>Молодцова Марина Анатольевна<span class="index">2</span></mark>, <mark>Козлова Светлана Валерьевна<span class="index">3</span></mark> и <mark>Юлия Викторовна<span class="index">4</span></mark> (помощн.воспит)- это те люди которые достойно и с совестью работают в своей профессии!!  <mark>Светлана Валерьевна<span class="index">5</span></mark>- это их "вечный двигатель" она всегда что-то придумывает; снимает,монтирует видео; играет с детьми!  <mark>Марина Анатольевна<span class="index">6</span></mark>- это воспитатель,который учит наших деток доброте, хорошим поступкам; читает книги, рассказывает разные интересные рассказы (даже на прогулках она заинтересовывают деток:)  <mark>Юлия Викторовна<span class="index">7</span></mark> - добрая, отзывчивая воспитатель! Имея опыт общения с детьми девочкам с ней особо интересно наряжаться, играть в девчачьи игры, ну и конечно дети любят помогать ей дежурить.  Восхищаюсь тем,сколько они все вместе занимаются рисованием,лепкой, аппликациями с детьми. Это каждый вечер я слышу "мам пойдем покажу что мы делали сегодня" и я Вам не могу передать то чувство счастья и спокойствия за своего ребенка, отдавая его в сад.   5-ая Группа. Малыши. Да,там маленькие детки 3-4года. Но и у них воспитатели самой высшей категории!! Это идеальное подходящие два воспитателя. <mark>Ронжина Ольга Николаевна<span class="index">8</span></mark> - это воспитатель- учитель,она вторая "мама" нашим детям. Занимается развитием речи,математикой,лепкой и многим другим, и конечно же ставит сценки с нашими малышами, помогает детям "адаптироваться" к сцене. Имеет к каждому ребенку особый подход!  <mark>Коновалов<span class="index">9</span></mark> <mark>Елена Ивановна<span class="index">10</span></mark> (Еленовна Ивановна,как говорит сын:)- это творческий воспитатель, с ней детки с удовольствием занимаются рисованием,лепкой, играют в подвижные игры и считают её своим другом!  <mark>Светлана Викторовна<span class="index">11</span></mark>(помощн.воспит.)- "палочка выручалочка" в нашей группе. Всегда следит чтобы все были сыты, чистые, и смотрит за всеми детками, помогает и так же участвует в играх,выступлениях,зарядке- в общем незаменимый человек.  В группе всегда веселая,добрая атмосфера. Ежедневно они что то творят с воспитателями, рисуют,раскрашивать,лепят,танцуют...   Подводя итог,хочу сказать что КАЖДЫЙ из воспитателей 5 и 6 группы с уважением,вниманием относятся к родителям своих воспитанников. Всегда ответят на все вопросы,касающиеся своего ребенка,отвечают искренне и подробно! Я безумно рада,что мои дети в надежных руках. Я доверяю своих детей этим людям и знаю, что все они сделают максимум,чтобы не толькр обеспечить безопасный присмотр,они ещё и разнообразят веселый досуг малышам.  <mark>Прошу Вас<span class="index">12</span></mark> отметить каждого педагога благодарностью от лица родителей.  Спасибо им за то,что родители,находясь на работе спокойны за своих чад.  Желаю вашей (нашей будущей) школе процветания и хороших результатов. И всем знакомым однозначно скажу,что наш сад и будущая школа лучшие в нашем районе!!   С уважением, <mark>Анна<span class="index">13</span></mark></div>
# =============

# %% [markdown]
# # Новости

# %%
news = list(load_lines(NEWS))

# %% [markdown]
# 4.6 текст/c

# %%
# %%time
extractor = NamesExtractor()
records1 = [extractor(_) for _ in log_progress(news)]
# Out:
# CPU times: user 3min 33s, sys: 1.83 s, total: 3min 35s
# Wall time: 3min 36s

# %% [markdown]
# 137 текст/c

# %%
# %%time
records2 = list(run_algfio_tomita(news * 10))
# Out:
# CPU times: user 3.43 s, sys: 2.03 s, total: 5.45 s
# Wall time: 1min 13s

# %% [markdown]
# ```bash
# time pypy pypy.py news.txt
# # 34,99s user 1,39s system 84% cpu 42,884 total
# ```
#
# 23.3 текст/c

# %%
# %run -n main.py
records = list(zip(news, records1, records2))
random_seed(41)
for text, matches1_, matches2_ in sample(records, 10):
    spans1 = sorted(_.span for _ in matches1_)
    spans2 = sorted(_.span for _ in matches2_)
    if spans1 != spans2:
        show_markup(text, spans1)
        print('-------------')
        show_markup(text, spans2)
        print('=============')
# Out:
# <style>
#
# .markup {
#     white-space: pre-wrap;
# }
#
# .markup > mark {
#     line-height: 1;
#     display: inline-block;
#     border-radius: 0.25em;
#     border: 1px solid #fdf07c;
#     background: #ffffc2;
# }
#
# .markup > mark > .index {
#     font-size: 0.7em;
#     vertical-align: top;
#     margin-left: 0.1em;
# }
#     </style><div class="markup tex2jax_ignore">Выступая на Совете безопасности ООН, главы инспекторов ООН <mark>Ханс Бликс<span class="index">0</span></mark> (Hans Blix) и <mark>Мохаммед<span class="index">1</span></mark> <mark>Эль<span class="index">2</span></mark>-Барадеи (Mohamed ElBaradei) заявили, что Ирак активно сотрудничает с инспекторами и предпринимает реальные шаги по разоружению, прередает АР. "Предпринятое уничтожение иракского оружия является значительным этапом разоружения, - заявил <mark>Бликс<span class="index">3</span></mark>. - Мы видим не уничтожение каких-то зубочисток. Уничтожают смертельно опасное оружие". Между тем, <mark>Бликс<span class="index">4</span></mark> не сказал, что Ирак избавился от всего оружия массового поражения. <mark>Бликс<span class="index">5</span></mark> заявил, что 81-миллиметровые трубы, закупленные Ираком, не были использованы для создания оборудования, пригодного для обогащения урана, как предполагали ранее. Он также подчеркнул, что Ирак активно сотрудничает с инспекторами ООН. По сведениям BBC News, <mark>Бликс<span class="index">6</span></mark> сообщил, что не обнаружено никаких свидетельств, подтверждающих существование в Ираке подземных мобильных лабораторий, занимающихся разработкой биологического и химического орудия, о которых сообщали США и Великобритания. Вместе с тем, он признал, что Ирак все еще не предоставил достаточных подтверждений того, что уничтожил имевшееся в его распоряжении оружие, и беседы и иракскими учеными проходят "под внешним давлением". В связи с этим <mark>Бликс<span class="index">7</span></mark> сообщил, что ООН будут добиваться возможности проводить беседы с иракскими учеными за пределами Ирака. Глава МАГАТЭ <mark>Мохаммед<span class="index">8</span></mark> <mark>Эль<span class="index">9</span></mark>-Барадеи также подчеркнул, что Ирак активно сотрудничает с ООН и предпринимает реальные шаги для разоружения. <mark>Эль<span class="index">10</span></mark>-Барадеи подчеркнул, что инспекторы МАГАТЭ не нашли никаких свидетельств того, что Ирак пытался закупить уран в <mark>Нигере<span class="index">11</span></mark> и обнаружили, что документы, свидетельствующие об этом, не являются подлинными. <mark>Эль<span class="index">12</span></mark>-Барадеи подтвердил, что инспекторы ООН не нашли никаких свидетельств того, что Ирак пытается возобновить исследования, проводимые в рамках программы по созданию ядерного оружия. "В течение последних нескольких недель, возможно, в результате усиливающегося международного давления, Ирак идет навстречу инспекторам ООН и сотрудничает с ними, - подчеркнул <mark>Эль<span class="index">13</span></mark>-Барадеи. - Я надеюсь, что Ирак продолжит расширять объем и ускорять темп этого сотрудничества". Руководитель групп инспекторов, ответственных за исследование иракских биологических, химических и ракетных программ, сообщили, что Ирак предоставил дополнительные документы, касающиеся сибирской язвы и нервно-паралитического агента VX. Как сообщает РИА "Новости", министр иностранных дел России <mark>Игорь Иванов<span class="index">14</span></mark>, выступая на Совете безопасности ООН, заявил, что впервые за многие годы в Ираке идет процесс реального разоружения. "В принципе,- отметил <mark>Иванов<span class="index">15</span></mark>,- мы согласны с мнением <mark>Ханса Бликса<span class="index">16</span></mark> о том, что если бы последние позитивные шаги Багдада были предприняты раньше, то и результаты сейчас были бы весомыми. Но важно, что эти шаги сделаны, и они, отмечает руководитель ЮНМОВИК, открывают путь" к решению иракской проблем. "Давайте еще раз взвесим, - сказал <mark>Иванов<span class="index">17</span></mark>,- что отвечает подлинным интересам мирового сообщества: продолжить пусть нелегкую, но приносящую осязаемые результаты работу инспекторов, или прибегнуть к силе, что неминуемо будет сопряжено с большими человеческими жертвами и обернется тяжелыми и непредсказуемыми последствиями для региональной и международной стабиль ...
# -------------
# <style>
#
# .markup {
#     white-space: pre-wrap;
# }
#
# .markup > mark {
#     line-height: 1;
#     display: inline-block;
#     border-radius: 0.25em;
#     border: 1px solid #fdf07c;
#     background: #ffffc2;
# }
#
# .markup > mark > .index {
#     font-size: 0.7em;
#     vertical-align: top;
#     margin-left: 0.1em;
# }
#     </style><div class="markup tex2jax_ignore">Выступая на Совете безопасности ООН, главы инспекторов ООН <mark>Ханс Бликс<span class="index">0</span></mark> (Hans Blix) и <mark>Мохаммед Эль-Барадеи<span class="index">1</span></mark> (Mohamed ElBaradei) заявили, что Ирак активно сотрудничает с инспекторами и предпринимает реальные шаги по разоружению, прередает АР. "Предпринятое уничтожение иракского оружия является значительным этапом разоружения, - заявил <mark>Бликс<span class="index">2</span></mark>. - Мы видим не уничтожение каких-то зубочисток. Уничтожают смертельно опасное оружие". Между тем, <mark>Бликс<span class="index">3</span></mark> не сказал, что Ирак избавился от всего оружия массового поражения. <mark>Бликс<span class="index">4</span></mark> заявил, что 81-миллиметровые трубы, закупленные Ираком, не были использованы для создания оборудования, пригодного для обогащения урана, как предполагали ранее. Он также подчеркнул, что Ирак активно сотрудничает с инспекторами ООН. По сведениям BBC News, <mark>Бликс<span class="index">5</span></mark> сообщил, что не обнаружено никаких свидетельств, подтверждающих существование в Ираке подземных мобильных лабораторий, занимающихся разработкой биологического и химического орудия, о которых сообщали США и Великобритания. Вместе с тем, он признал, что Ирак все еще не предоставил достаточных подтверждений того, что уничтожил имевшееся в его распоряжении оружие, и беседы и иракскими учеными проходят "под внешним давлением". В связи с этим <mark>Бликс<span class="index">6</span></mark> сообщил, что ООН будут добиваться возможности проводить беседы с иракскими учеными за пределами Ирака. Глава МАГАТЭ <mark>Мохаммед Эль-Барадеи<span class="index">7</span></mark> также подчеркнул, что Ирак активно сотрудничает с ООН и предпринимает реальные шаги для разоружения. <mark>Эль-Барадеи<span class="index">8</span></mark> подчеркнул, что инспекторы МАГАТЭ не нашли никаких свидетельств того, что Ирак пытался закупить уран в Нигере и обнаружили, что документы, свидетельствующие об этом, не являются подлинными. <mark>Эль-Барадеи<span class="index">9</span></mark> подтвердил, что инспекторы ООН не нашли никаких свидетельств того, что Ирак пытается возобновить исследования, проводимые в рамках программы по созданию ядерного оружия. "В течение последних нескольких недель, возможно, в результате усиливающегося международного давления, Ирак идет навстречу инспекторам ООН и сотрудничает с ними, - подчеркнул <mark>Эль-Барадеи<span class="index">10</span></mark>. - Я надеюсь, что Ирак продолжит расширять объем и ускорять темп этого сотрудничества". Руководитель групп инспекторов, ответственных за исследование иракских биологических, химических и ракетных программ, сообщили, что Ирак предоставил дополнительные документы, касающиеся сибирской язвы и нервно-паралитического агента VX. Как сообщает РИА "Новости", министр иностранных дел России <mark>Игорь Иванов<span class="index">11</span></mark>, выступая на Совете безопасности ООН, заявил, что впервые за многие годы в Ираке идет процесс реального разоружения. "В принципе,- отметил <mark>Иванов<span class="index">12</span></mark>,- мы согласны с мнением <mark>Ханса<span class="index">13</span></mark> <mark>Бликса<span class="index">14</span></mark> о том, что если бы последние позитивные шаги Багдада были предприняты раньше, то и результаты сейчас были бы весомыми. Но важно, что эти шаги сделаны, и они, отмечает руководитель ЮНМОВИК, открывают путь" к решению иракской проблем. "Давайте еще раз взвесим, - сказал <mark>Иванов<span class="index">15</span></mark>,- что отвечает подлинным интересам мирового сообщества: продолжить пусть нелегкую, но приносящую осязаемые результаты работу инспекторов, или прибегнуть к силе, что неминуемо будет сопряжено с большими человеческими жертвами и обернется тяжелыми и непредсказуемыми последствиями для региональной и международной стабильности".</div>
# =============
# <style>
#
# .markup {
#     white-space: pre-wrap;
# }
#
# .markup > mark {
#     line-height: 1;
#     display: inline-block;
#     border-radius: 0.25em;
#     border: 1px solid #fdf07c;
#     background: #ffffc2;
# }
#
# .markup > mark > .index {
#     font-size: 0.7em;
#     vertical-align: top;
#     margin-left: 0.1em;
# }
#     </style><div class="markup tex2jax_ignore">Актерский состав фильма "Семь психопатов" пополнился <mark>Томом Уэйтсом<span class="index">0</span></mark>, <mark>Ольгой Куриленко<span class="index">1</span></mark> и Вуди <mark>Харрельсоном<span class="index">2</span></mark>, сообщается на сайте Collider. Ранее уже было известно, что в картине снимутся <mark>Колин<span class="index">3</span></mark> Фаррелл, <mark>Кристофер Уокен<span class="index">4</span></mark> и <mark>Сэм<span class="index">5</span></mark> Рокуэлл. Кроме того, предполагалось, что одного из персонажей (гангстера, у которого крадут собаку) сыграет <mark>Микки Рурк<span class="index">6</span></mark>. Однако в начале ноября стало известно, что актер отказался от участия в проекте и при этом довольно негативно отозвался о режиссере картины <mark>Мартине<span class="index">7</span></mark> Макдонахе. Теперь стало известно, что предлагавшуюся <mark>Рурку<span class="index">8</span></mark> роль исполнит Вуди <mark>Харрельсон<span class="index">9</span></mark>. Лента "Семь психопатов" позиционируется как черная комедия. Макдонах работает над фильмом не только в качестве режиссера, но и как сценарист. Предыдущая лента <mark>Мартина<span class="index">10</span></mark> называлась "Залечь на дно в Брюгге" и вышла в прокат в 2007 году. В этой картине также снялся <mark>Колин<span class="index">11</span></mark> Фаррелл.</div>
# -------------
# <style>
#
# .markup {
#     white-space: pre-wrap;
# }
#
# .markup > mark {
#     line-height: 1;
#     display: inline-block;
#     border-radius: 0.25em;
#     border: 1px solid #fdf07c;
#     background: #ffffc2;
# }
#
# .markup > mark > .index {
#     font-size: 0.7em;
#     vertical-align: top;
#     margin-left: 0.1em;
# }
#     </style><div class="markup tex2jax_ignore">Актерский состав фильма "Семь психопатов" пополнился <mark>Томом Уэйтсом<span class="index">0</span></mark>, <mark>Ольгой Куриленко<span class="index">1</span></mark> и <mark>Вуди Харрельсоном<span class="index">2</span></mark>, сообщается на сайте Collider. Ранее уже было известно, что в картине снимутся <mark>Колин Фаррелл<span class="index">3</span></mark>, <mark>Кристофер Уокен<span class="index">4</span></mark> и <mark>Сэм Рокуэлл<span class="index">5</span></mark>. Кроме того, предполагалось, что одного из персонажей (гангстера, у которого крадут собаку) сыграет <mark>Микки Рурк<span class="index">6</span></mark>. Однако в начале ноября стало известно, что актер отказался от участия в проекте и при этом довольно негативно отозвался о режиссере картины <mark>Мартине Макдонахе<span class="index">7</span></mark>. Теперь стало известно, что предлагавшуюся <mark>Рурку<span class="index">8</span></mark> роль исполнит <mark>Вуди Харрельсон<span class="index">9</span></mark>. Лента "Семь психопатов" позиционируется как черная комедия. <mark>Макдонах<span class="index">10</span></mark> работает над фильмом не только в качестве режиссера, но и как сценарист. Предыдущая лента <mark>Мартина<span class="index">11</span></mark> называлась "Залечь на дно в Брюгге" и вышла в прокат в 2007 году. В этой картине также снялся <mark>Колин Фаррелл<span class="index">12</span></mark>.</div>
# =============
# <style>
#
# .markup {
#     white-space: pre-wrap;
# }
#
# .markup > mark {
#     line-height: 1;
#     display: inline-block;
#     border-radius: 0.25em;
#     border: 1px solid #fdf07c;
#     background: #ffffc2;
# }
#
# .markup > mark > .index {
#     font-size: 0.7em;
#     vertical-align: top;
#     margin-left: 0.1em;
# }
#     </style><div class="markup tex2jax_ignore">Министр иностранных дел России <mark>Сергей Лавров<span class="index">0</span></mark> заявил, что, согласно его информации, "кое-кто" поставляет в Ливию "кое-какое" запрещенное оборудование. "Я слышал о том, что уже кое-какое военно-экспертное и техническое ноу-хау передается на земле, слышал о том, что кое-кто уже поставляет в Ливию оружие", - цитирует главу внешнеполитического ведомства РФ "Интерфакс". По мнению Лаврова, не уточнившего источника своей информации, указанные действия являются нарушением резолюции Совета Безопасности ООН номер 1970, запрещающей такие поставки. На вопрос об отношении к слухам об использовании коалицией боеприпасов с обедненным ураном, министр прямо отвечать не стал, отметив, что ничего по этой теме сказать не может, но если информация подтвердится, "то нужно с этим разбираться". Кроме того, <mark>Лавров<span class="index">1</span></mark> еще раз подтвердил, что Москва выступает за перевод конфликта из военного в политическое русло и поддержал мирную инициативу Африканского союза, уже отвергнутую Западом и повстанцами в Бенгази. "Принципиально важно не подыгрывать настроениям в пользу решения проблем и в Ливии, и в любой другой стране этого региона путем применения чрезмерной военной силы", - поделился своими соображениями российский министр. При этом он добавил, что задачей мирового сообщества является защита мирных граждан. Министр также затронул тему возможной наземной операции, слухи о которой начали распространяться в последнее время в различных СМИ. По его мнению, такая операция была бы незаконной, поскольку резолюция ООН прямо запрещает ее проведение. Как сообщалось ранее, Россия не стала возражать против резолюции, санкционировавшей бомбардировки войск <mark>Муаммара Каддафи<span class="index">2</span></mark>, однако потом стала выражать озабоченность по поводу "чрезмерного применения силы" участниками коалиции. Кроме того, президент РФ <mark>Дмитрий Медведев<span class="index">3</span></mark> высказал мнение, что западные страны, участвующие в военной кампании в Ливии, своими действиями превысили полномочия, которыми их наделила соответствующая резолюция Совета безопасности ООН.</div>
# -------------
# <style>
#
# .markup {
#     white-space: pre-wrap;
# }
#
# .markup > mark {
#     line-height: 1;
#     display: inline-block;
#     border-radius: 0.25em;
#     border: 1px solid #fdf07c;
#     background: #ffffc2;
# }
#
# .markup > mark > .index {
#     font-size: 0.7em;
#     vertical-align: top;
#     margin-left: 0.1em;
# }
#     </style><div class="markup tex2jax_ignore">Министр иностранных дел России <mark>Сергей Лавров<span class="index">0</span></mark> заявил, что, согласно его информации, "кое-кто" поставляет в <mark>Ливию<span class="index">1</span></mark> "кое-какое" запрещенное оборудование. "Я слышал о том, что уже кое-какое военно-экспертное и техническое ноу-хау передается на земле, слышал о том, что кое-кто уже поставляет в <mark>Ливию<span class="index">2</span></mark> оружие", - цитирует главу внешнеполитического ведомства РФ "Интерфакс". По мнению <mark>Лаврова<span class="index">3</span></mark>, не уточнившего источника своей информации, указанные действия являются нарушением резолюции Совета Безопасности ООН номер 1970, запрещающей такие поставки. На вопрос об отношении к слухам об использовании коалицией боеприпасов с обедненным ураном, министр прямо отвечать не стал, отметив, что ничего по этой теме сказать не может, но если информация подтвердится, "то нужно с этим разбираться". Кроме того, <mark>Лавров<span class="index">4</span></mark> еще раз подтвердил, что Москва выступает за перевод конфликта из военного в политическое русло и поддержал мирную инициативу Африканского союза, уже отвергнутую Западом и повстанцами в Бенгази. "Принципиально важно не подыгрывать настроениям в пользу решения проблем и в <mark>Ливии<span class="index">5</span></mark>, и в любой другой стране этого региона путем применения чрезмерной военной силы", - поделился своими соображениями российский министр. При этом он добавил, что задачей мирового сообщества является защита мирных граждан. Министр также затронул тему возможной наземной операции, слухи о которой начали распространяться в последнее время в различных СМИ. По его мнению, такая операция была бы незаконной, поскольку резолюция ООН прямо запрещает ее проведение. Как сообщалось ранее, Россия не стала возражать против резолюции, санкционировавшей бомбардировки войск <mark>Муаммара Каддафи<span class="index">6</span></mark>, однако потом стала выражать озабоченность по поводу "чрезмерного применения силы" участниками коалиции. Кроме того, президент РФ <mark>Дмитрий Медведев<span class="index">7</span></mark> высказал мнение, что западные страны, участвующие в военной кампании в <mark>Ливии<span class="index">8</span></mark>, своими действиями превысили полномочия, которыми их наделила соответствующая резолюция Совета безопасности ООН.</div>
# =============
# <style>
#
# .markup {
#     white-space: pre-wrap;
# }
#
# .markup > mark {
#     line-height: 1;
#     display: inline-block;
#     border-radius: 0.25em;
#     border: 1px solid #fdf07c;
#     background: #ffffc2;
# }
#
# .markup > mark > .index {
#     font-size: 0.7em;
#     vertical-align: top;
#     margin-left: 0.1em;
# }
#     </style><div class="markup tex2jax_ignore">Ростовский областной суд вынес приговор насильнику-педофилу, которого признали виновным в сексуальном насилии над девочками в возрасте до 14 лет. Как говорится в сообщении пресс-службы СКП РФ, <mark>Виктор Новосинский<span class="index">0</span></mark> приговорен к 15 годам лишения свободы с отбыванием наказания в колонии строгого режима. Всего от рук маньяка в Ростове пострадали 14 девочек. Согласно материалам дела, с января по май 2007 года преступник заманивал детей в безлюдные места и там, угрожая убийством, насиловал их. По данным газеты "Комсомольская правда", <mark>Новосинский<span class="index">1</span></mark>, выбрав себе жертву, обещал девочке подарить котенка или белочку, после чего она шла с насильником. Поймали маньяка на кладбище, куда он привел очередную жертву. Мужчину с ребенком окликнули дежурившие там милиционеры, <mark>Новосинский<span class="index">2</span></mark> испугался и попытался убежать, однако был задержан. Отмечается, что в прошлом насильник уже отсидел 10 лет за аналогичные преступления.</div>
# -------------
# <style>
#
# .markup {
#     white-space: pre-wrap;
# }
#
# .markup > mark {
#     line-height: 1;
#     display: inline-block;
#     border-radius: 0.25em;
#     border: 1px solid #fdf07c;
#     background: #ffffc2;
# }
#
# .markup > mark > .index {
#     font-size: 0.7em;
#     vertical-align: top;
#     margin-left: 0.1em;
# }
#     </style><div class="markup tex2jax_ignore">Ростовский областной суд вынес приговор насильнику-педофилу, которого признали виновным в сексуальном насилии над девочками в возрасте до 14 лет. Как говорится в сообщении пресс-службы СКП РФ, <mark>Виктор Новосинский<span class="index">0</span></mark> приговорен к 15 годам лишения свободы с отбыванием наказания в колонии строгого режима. Всего от рук маньяка в <mark>Ростове<span class="index">1</span></mark> пострадали 14 девочек. Согласно материалам дела, с января по май 2007 года преступник заманивал детей в безлюдные места и там, угрожая убийством, насиловал их. По данным газеты "Комсомольская правда", <mark>Новосинский<span class="index">2</span></mark>, выбрав себе жертву, обещал девочке подарить котенка или белочку, после чего она шла с насильником. Поймали маньяка на кладбище, куда он привел очередную жертву. Мужчину с ребенком окликнули дежурившие там милиционеры, <mark>Новосинский<span class="index">3</span></mark> испугался и попытался убежать, однако был задержан. Отмечается, что в прошлом насильник уже отсидел 10 лет за аналогичные преступления.</div>
# =============
# <style>
#
# .markup {
#     white-space: pre-wrap;
# }
#
# .markup > mark {
#     line-height: 1;
#     display: inline-block;
#     border-radius: 0.25em;
#     border: 1px solid #fdf07c;
#     background: #ffffc2;
# }
#
# .markup > mark > .index {
#     font-size: 0.7em;
#     vertical-align: top;
#     margin-left: 0.1em;
# }
#     </style><div class="markup tex2jax_ignore">7 июня жителю Киева удалось сорвать рекордный для Украины <mark>джек<span class="index">0</span></mark>-пот, сообщается на сайте Украинской национальной лотереи. Розыгрыши Супер-Лото проходят на Украине с 2001 года. 7 июня лотерея разыгрывала беспрецедентный <mark>джек<span class="index">1</span></mark>-пот - 10 миллионов гривен (около 2-х миллионов долларов). Сумма являлась максимально возможным выигрышем в этой игре. Все 6 счастливых чисел удалось угадать киевлянину, который купил свой билет вечером незадолго до окончания продаж. Он сделал ставку в 3 гривны и получил в итоге 10 миллионов 37 тысяч 125 гривен. По данным Украинской национальной лотереи, всего с апреля 2001 года в Супер-Лото было разыграно 43 <mark>джек<span class="index">2</span></mark>-пота. Прежний рекорд составлял 8,1 миллиона гривен, которые 1 декабря 2004 года выиграл также киевлянин.</div>
# -------------
# <style>
#
# .markup {
#     white-space: pre-wrap;
# }
#
# .markup > mark {
#     line-height: 1;
#     display: inline-block;
#     border-radius: 0.25em;
#     border: 1px solid #fdf07c;
#     background: #ffffc2;
# }
#
# .markup > mark > .index {
#     font-size: 0.7em;
#     vertical-align: top;
#     margin-left: 0.1em;
# }
#     </style><div class="markup tex2jax_ignore">7 июня жителю Киева удалось сорвать рекордный для Украины джек-пот, сообщается на сайте Украинской национальной лотереи. Розыгрыши Супер-Лото проходят на Украине с 2001 года. 7 июня лотерея разыгрывала беспрецедентный джек-пот - 10 миллионов гривен (около 2-х миллионов долларов). Сумма являлась максимально возможным выигрышем в этой игре. Все 6 счастливых чисел удалось угадать киевлянину, который купил свой билет вечером незадолго до окончания продаж. Он сделал ставку в 3 гривны и получил в итоге 10 миллионов 37 тысяч 125 гривен. По данным Украинской национальной лотереи, всего с апреля 2001 года в Супер-Лото было разыграно 43 джек-пота. Прежний рекорд составлял 8,1 миллиона гривен, которые 1 декабря 2004 года выиграл также киевлянин.</div>
# =============
# <style>
#
# .markup {
#     white-space: pre-wrap;
# }
#
# .markup > mark {
#     line-height: 1;
#     display: inline-block;
#     border-radius: 0.25em;
#     border: 1px solid #fdf07c;
#     background: #ffffc2;
# }
#
# .markup > mark > .index {
#     font-size: 0.7em;
#     vertical-align: top;
#     margin-left: 0.1em;
# }
#     </style><div class="markup tex2jax_ignore">Переговоры президента России <mark>Владимира Путина<span class="index">0</span></mark> и его французского коллеги <mark>Франсуа Олланда<span class="index">1</span></mark> прошли в «конструктивном и прагматическом духе», сообщил пресс-секретарь российского лидера <mark>Дмитрий Песков<span class="index">2</span></mark>. На встрече в Ереване в пятницу, 24 апреля, лидеры стран обсудили вопрос поставок «Мистралей», а также затронули ситуацию на Украине и процесс выполнения минских договоренностей, передает ТАСС. «С президентом Олландом состоялась достаточно продолжительная и очень обстоятельная беседа», — отметил <mark>Песков<span class="index">3</span></mark>. По его словам, стороны обсудили целый ряд вопросов. «"Мистрали" тоже затрагивались, в данном случае никаких проблем нет», — подчеркнул пресс-секретарь российского лидера. <mark>Песков<span class="index">4</span></mark> добавил, что <mark>Путин<span class="index">5</span></mark> «еще раз дал необходимые разъяснения в связи с темой комплексов С-300 для Ирана». В отношении ситуации на Украине, главы государств затронули вопрос привлечения США к переговорам в «нормандском формате». «Эта тема упоминалась, но не предметно», — пояснил пресс-секретарь. В целом, подчеркнул он, в ходе переговоров «была отмечена необходимость недопущения деградации очень богатых с точки зрения различных измерений двухсторонних французско-российских отношений». Ранее в пятницу Олланд, комментируя итоги встречи с <mark>Путиным<span class="index">6</span></mark>, заявил, что решение о судьбе вертолетоносцев «Мистраль» пока не принято. При этом информированный источник Reuters отметил, что Россия и Франция в ближайшее время расторгнут контракт на поставку «Мистралей». Источник ТАСС в дипломатических кругах, в свою очередь, заявил, что в Москве считают приемлемой суммой неустойки полтора миллиарда евро. 22 апреля <mark>Франсуа Олланд<span class="index">7</span></mark> заявил, что Франция и Россия при рассмотрении вопроса о передаче Москве «Мистралей» исходят из того, что Париж либо осуществит поставку и получит за это деньги, либо возместит расходы заказчикам. При этом он добавил, что в текущих условиях поставка кораблей России по-прежнему не представляется ему возможной. 19 апреля президент Франции объявил о намерении обсудить возможные варианты решения проблемы «Мистралей» с российским лидером. Согласно условиям контракта на строительство двух кораблей типа «Мистраль» стоимостью 1,2 миллиарда евро, заключенного в июне 2011 года, первый вертолетоносец («Владивосток») Франция должна была передать России еще в ноябре 2014-го, срок сдачи «Севастополя» истекает 1 ноября 2015 года. Сумма неустоек и штрафов за неисполнение договора поставки кораблей может достигнуть трех миллиардов евро. Однако на прямой линии 16 апреля <mark>Владимир Путин<span class="index">8</span></mark> заявил, что Россия не собирается требовать у Франции неустойки за срыв графика поставок кораблей.</div>
# -------------
# <style>
#
# .markup {
#     white-space: pre-wrap;
# }
#
# .markup > mark {
#     line-height: 1;
#     display: inline-block;
#     border-radius: 0.25em;
#     border: 1px solid #fdf07c;
#     background: #ffffc2;
# }
#
# .markup > mark > .index {
#     font-size: 0.7em;
#     vertical-align: top;
#     margin-left: 0.1em;
# }
#     </style><div class="markup tex2jax_ignore">Переговоры президента России <mark>Владимира Путина<span class="index">0</span></mark> и его французского коллеги <mark>Франсуа Олланда<span class="index">1</span></mark> прошли в «конструктивном и прагматическом духе», сообщил пресс-секретарь российского лидера <mark>Дмитрий Песков<span class="index">2</span></mark>. На встрече в Ереване в пятницу, 24 апреля, лидеры стран обсудили вопрос поставок «Мистралей», а также затронули ситуацию на Украине и процесс выполнения минских договоренностей, передает ТАСС. «С президентом <mark>Олландом<span class="index">3</span></mark> состоялась достаточно продолжительная и очень обстоятельная беседа», — отметил <mark>Песков<span class="index">4</span></mark>. По его словам, стороны обсудили целый ряд вопросов. «"Мистрали" тоже затрагивались, в данном случае никаких проблем нет», — подчеркнул пресс-секретарь российского лидера. <mark>Песков<span class="index">5</span></mark> добавил, что <mark>Путин<span class="index">6</span></mark> «еще раз дал необходимые разъяснения в связи с темой комплексов С-300 для Ирана». В отношении ситуации на Украине, главы государств затронули вопрос привлечения США к переговорам в «нормандском формате». «Эта тема упоминалась, но не предметно», — пояснил пресс-секретарь. В целом, подчеркнул он, в ходе переговоров «была отмечена необходимость недопущения деградации очень богатых с точки зрения различных измерений двухсторонних французско-российских отношений». Ранее в пятницу <mark>Олланд<span class="index">7</span></mark>, комментируя итоги встречи с <mark>Путиным<span class="index">8</span></mark>, заявил, что решение о судьбе вертолетоносцев «Мистраль» пока не принято. При этом информированный источник Reuters отметил, что Россия и Франция в ближайшее время расторгнут контракт на поставку «Мистралей». Источник ТАСС в дипломатических кругах, в свою очередь, заявил, что в Москве считают приемлемой суммой неустойки полтора миллиарда евро. 22 апреля <mark>Франсуа Олланд<span class="index">9</span></mark> заявил, что Франция и Россия при рассмотрении вопроса о передаче Москве «Мистралей» исходят из того, что Париж либо осуществит поставку и получит за это деньги, либо возместит расходы заказчикам. При этом он добавил, что в текущих условиях поставка кораблей России по-прежнему не представляется ему возможной. 19 апреля президент Франции объявил о намерении обсудить возможные варианты решения проблемы «Мистралей» с российским лидером. Согласно условиям контракта на строительство двух кораблей типа «Мистраль» стоимостью 1,2 миллиарда евро, заключенного в июне 2011 года, первый вертолетоносец («Владивосток») Франция должна была передать России еще в ноябре 2014-го, срок сдачи «Севастополя» истекает 1 ноября 2015 года. Сумма неустоек и штрафов за неисполнение договора поставки кораблей может достигнуть трех миллиардов евро. Однако на прямой линии 16 апреля <mark>Владимир Путин<span class="index">10</span></mark> заявил, что Россия не собирается требовать у Франции неустойки за срыв графика поставок кораблей.</div>
# =============
# <style>
#
# .markup {
#     white-space: pre-wrap;
# }
#
# .markup > mark {
#     line-height: 1;
#     display: inline-block;
#     border-radius: 0.25em;
#     border: 1px solid #fdf07c;
#     background: #ffffc2;
# }
#
# .markup > mark > .index {
#     font-size: 0.7em;
#     vertical-align: top;
#     margin-left: 0.1em;
# }
#     </style><div class="markup tex2jax_ignore">Апелляционный суд Днепропетровской области признал неправомерным постановление Кировского районного суда Днепропетровска, который ранее запретил Партии регионов <mark>Виктора Януковича<span class="index">0</span></mark> участвовать в выборах в местный областной совет в связи с нарушениями в ходе предвыборной агитации. Как пишет в четверг газета "Дело", в определении Апелляционного суда указано, что достаточных оснований для признания факта нарушений со стороны "регионалов" не было. Как ранее сообщали украинские СМИ, 17 марта по иску областного отделения Народного Руха Украины Кировский суд признал факт подкупа избирателей, а также незаконной агитации и использования средств вне избирательного фонда со стороны кандидатов в Днепропетровский облсовет от Партии регионов. Поводом решения суда послужило то, что 8 марта "регионалы" якобы вручали подарки ветеранам войны, где присутствовала партийная символика. 20 марта  в знак протеста против снятия с выборов Партия регионов установила у здания облсовета палаточный городок. Глава днепропетровского отделения Партии регионов <mark>Олег Царев<span class="index">1</span></mark> после оглашения решения Апелляционного суда сообщил, что члены партии в целом им удовлетворены, и все палатки из-под стен Днепропетровского облсовета в ближайшем будущем снимут. В то же время, по мнению <mark>Царева<span class="index">2</span></mark>, сам конфликт был инициирован не без вмешательства местного штаба пропрезидентской партии "Наша Украина". Он уверен, что " все это было попыткой отработать сценарий по снятию Партии регионов с выборов, чтобы затем запустить его по всей стране". В свою очередь руководитель регионального избирательного штаба "Нашей Украины" в Днепропетровске <mark>Сергей Бычков<span class="index">3</span></mark> опроверг эти обвинения. "Никакого отношения наш блок к решению суда не имеет и на суд не мог влиять", - заявил Бычков.</div>
# -------------
# <style>
#
# .markup {
#     white-space: pre-wrap;
# }
#
# .markup > mark {
#     line-height: 1;
#     display: inline-block;
#     border-radius: 0.25em;
#     border: 1px solid #fdf07c;
#     background: #ffffc2;
# }
#
# .markup > mark > .index {
#     font-size: 0.7em;
#     vertical-align: top;
#     margin-left: 0.1em;
# }
#     </style><div class="markup tex2jax_ignore">Апелляционный суд Днепропетровской области признал неправомерным постановление Кировского районного суда Днепропетровска, который ранее запретил Партии регионов <mark>Виктора Януковича<span class="index">0</span></mark> участвовать в выборах в местный областной совет в связи с нарушениями в ходе предвыборной агитации. Как пишет в четверг газета "Дело", в определении Апелляционного суда указано, что достаточных оснований для признания факта нарушений со стороны "регионалов" не было. Как ранее сообщали украинские СМИ, 17 марта по иску областного отделения Народного Руха Украины Кировский суд признал факт подкупа избирателей, а также незаконной агитации и использования средств вне избирательного фонда со стороны кандидатов в Днепропетровский облсовет от Партии регионов. Поводом решения суда послужило то, что 8 марта "регионалы" якобы вручали подарки ветеранам войны, где присутствовала партийная символика. 20 марта  в знак протеста против снятия с выборов Партия регионов установила у здания облсовета палаточный городок. Глава днепропетровского отделения Партии регионов <mark>Олег Царев<span class="index">1</span></mark> после оглашения решения Апелляционного суда сообщил, что члены партии в целом им удовлетворены, и все палатки из-под стен Днепропетровского облсовета в ближайшем будущем снимут. В то же время, по мнению <mark>Царева<span class="index">2</span></mark>, сам конфликт был инициирован не без вмешательства местного штаба пропрезидентской партии "Наша Украина". Он уверен, что " все это было попыткой отработать сценарий по снятию Партии регионов с выборов, чтобы затем запустить его по всей стране". В свою очередь руководитель регионального избирательного штаба "Нашей Украины" в Днепропетровске <mark>Сергей Бычков<span class="index">3</span></mark> опроверг эти обвинения. "Никакого отношения наш блок к решению суда не имеет и на суд не мог влиять", - заявил <mark>Бычков<span class="index">4</span></mark>.</div>
# =============
